# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plotting univariate histograms

# %%
penguins = pd.read_csv('D:\seaborn-dataset\seaborn-data-master\penguins.csv')
sns.displot(data=penguins, x='flipper_length_mm')

# %%
sns.displot(penguins, x='flipper_length_mm', binwidth=3)

# %%
sns.displot(penguins, x='flipper_length_mm', bins=20)

# %%
tips = sns.load_dataset('tips')
sns.displot(tips, x='size')

# %%
sns.displot(tips, x='size', bins = [1,2,3,4,5,6,7])

# %%
# sns.displot(tips, x='size', bins = len(tips['size']), discrete=True)
sns.displot(tips, x='size', discrete=True)

# %%
sns.displot(tips, x='day', shrink = .5)

# %% [markdown]
# ### Conditioning on other variables

# %%
sns.displot(penguins, x="flipper_length_mm", hue='species')

# %%
sns.displot(penguins, x="flipper_length_mm", 
            hue='species', element='step')

# %%
sns.displot(penguins, x="flipper_length_mm", 
            hue='species', multiple='stack')

# %%
sns.displot(penguins, x="flipper_length_mm", 
            hue='sex', multiple='dodge')

# %%
sns.displot(penguins, x="flipper_length_mm", col='sex')

# %% [markdown]
# ### Normalized histogram statistics

# %%
sns.displot(penguins, x="flipper_length_mm", 
            hue='species', stat='density',)

# %%
sns.displot(penguins, x="flipper_length_mm", 
            hue='species', stat='density', common_norm=False)

# %%
sns.displot(penguins, x="flipper_length_mm", 
            hue='species', stat='probability')

# %% [markdown]
# ### Kernel density estimation

# %%
sns.displot(penguins, x="flipper_length_mm", kind='kde')

# %% [markdown]
# ### Choosing the smoothing bandwidth

# %%
sns.displot(penguins, x="flipper_length_mm", 
            kind='kde', bw_adjust=.25)

# %%
sns.displot(penguins, x="flipper_length_mm", 
            kind='kde', bw_adjust = 2)

# %% [markdown]
# ### Conditioning on other variables

# %%
sns.displot(penguins, x="flipper_length_mm", 
            hue='species', kind='kde')

# %%
sns.displot(penguins, x="flipper_length_mm", 
            hue='species', kind='kde', multiple='stack')

# %%
# sns.displot(penguins, x="flipper_length_mm", 
#             hue='species', kind='kde',fill=False,multiple="stack", )
sns.displot(penguins, x="flipper_length_mm", 
            hue='species', kind='kde',multiple="stack", )

# %% [markdown]
# ### Kernal density estimation pitfalls

# %%
sns.displot(tips, x='total_bill', kind='kde')

# %%
sns.displot(tips, x='total_bill', kind='kde', cut=0)

# %%
diamonds = pd.read_csv("D:\seaborn-dataset\seaborn-data-master\diamonds.csv")
sns.displot(diamonds, x='carat', kind='kde')

# %%
sns.displot(diamonds, x='carat',)

# %%
sns.displot(diamonds, x='carat', kde=True)

# %% [markdown]
# ### Empirical cumulative distributions

# %%
sns.displot(penguins, x=penguins['flipper_length_mm'], 
            kind='ecdf')

# %%
sns.displot(penguins, x='flipper_length_mm', hue= 'species',
            kind='ecdf')

# %% [markdown]
# ### Visualizzaing bivariate distributions

# %%
sns.displot(penguins, x='flipper_length_mm', 
            y='bill_depth_mm')

# %%
sns.displot(penguins, x='flipper_length_mm', 
            y='bill_depth_mm', kind='kde')

# %%
sns.displot(penguins, x='bill_length_mm', 
            y='bill_depth_mm', hue='species')

# %%
sns.displot(penguins, x='bill_length_mm', 
            y='bill_depth_mm', kind='kde', hue='species')

# %%
sns.displot(penguins, x='bill_length_mm', 
            y='bill_depth_mm', binwidth=(2, .5))

# %%
sns.displot(penguins, x='bill_length_mm', 
            y='bill_depth_mm', binwidth=(2, .5), cbar=True)

# %%
sns.displot(penguins, x='bill_length_mm', y='bill_depth_mm', 
            kind='kde', thresh=.2, levels=4)

# %%
sns.displot(penguins, x='bill_length_mm', y='bill_depth_mm', 
            kind='kde', levels=[.01, .05, .1, .8])

# %%
sns.displot(diamonds, x='price', y='clarity', 
            log_scale=(True, False))

# %%
sns.displot(diamonds, x='color', y='clarity')

# %% [markdown]
# ### Distribution visualization in other settings

# %% [markdown]
# #### Plotting joint and marginal distributions

# %%
sns.jointplot(penguins, x='bill_length_mm', y='bill_depth_mm')

# %%
sns.jointplot(penguins, x='bill_length_mm', y='bill_depth_mm',
              hue='species', kind='kde')

# %%
g = sns.JointGrid(penguins, x='bill_length_mm', y='bill_depth_mm')
g.plot_joint(sns.histplot)
g.plot_marginals(sns.boxplot)

# %%
sns.displot(penguins, x='bill_length_mm', y='bill_depth_mm',
            kind='kde', rug=True)

# %%
sns.relplot(penguins, x='bill_length_mm', y='bill_depth_mm')
sns.rugplot(penguins, x='bill_length_mm', y='bill_depth_mm')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %% [markdown]
# ### Plotting many distributions

# %%
sns.pairplot(penguins)

# %%
g = sns.PairGrid(penguins)
g.map_upper(sns.histplot)
g.map_lower(sns.kdeplot, fill=True)
g.map_diag(sns.histplot, kde=True)
